# %% [markdown]
# # Menu

# %% [markdown]
# Written by Sebastian Lynch

# %% [markdown]
# ## Preprocessing

# %%
import Preprocessing as clean
import Genres as genres
import Artist as artist
import Top5 as top5
import ipywidgets as widgets  
from ipywidgets import Layout
from IPython.display import display, clear_output

# %% [markdown]
# The first cell imports our 4 .py program files, as well as the ipywidgets package necessary for creating interactive widgets.

# %%
clean.main()

# %% [markdown]
# The second cell calls the main function of Preprocessing.py. This function creates and populates MusicDatabase.db with data from songs.csv. On top of first cleaning and formatting the data in the manner specified by section 1.2 of the coursework specification, I have removed duplicate records after noticing that Laffy Taffy by D4L (2005) is entered twice.

# %% [markdown]
# ## The Main Menu

# %%
############
#----Main--- 
############

# Output widgets for each functionality
genre_output = widgets.Output()
artist_output = widgets.Output()
top5_output = widgets.Output()

# Function to handle genre functionality
def run_genre_functionality(year):
    with genre_output:
        clear_output(wait = True)
        print(f"Running genre analysis for year: {year}")
        genres.main(year)

# Function to handle artist functionality
def run_artist_functionality(artist_name):
    with artist_output:
        clear_output(wait = True)
        print(f"Running artist analysis for: {artist_name}")
        artist.main(artist_name)

# Function to display all Artist Names
def display_artist_list(_):
    with artist_output:
        clear_output()
        print("Artist Names (Alphabetical Order):")
        artist_list = artist.name_list()
        return artist_list

# Function to handle top 5 artists functionality
def run_top5_functionality(start_year, end_year):
    with top5_output:
        clear_output(wait = True)
        print(f"Running top 5 artist analysis for year range: {start_year} - {end_year}")
        top5.main(start_year, end_year)

# Genre analysis widget
genre_description = widgets.HTML(
    "<p><b>Genre Analysis:</b> Analyse the danceability, popularity, expletiveness and \
     distribution of music genres for a selected year from 1998-2020.</p>"
)
genre_year_input = widgets.IntSlider(
    description = "Year:",
    value = 2009,
    min = 1998,     # Minimum value
    max = 2020,    # Maximum value
    style = {'description_width': 'initial'}
)
genre_run_button = widgets.Button(description = "Run Genre Analysis")
genre_run_button.on_click(lambda _: run_genre_functionality(genre_year_input.value))

# Artist analysis widget
artist_description = widgets.HTML(
    "<p><b>Artist Analysis:</b> View the average popularity for a specific artist \
    and compare it against the overall average across all genres. You can view a\
    full list of the included artists by pressing 'Show Artist List'.</p>"
)
artist_name_input = widgets.Text(
    description = "Artist Name:",
    placeholder = "Enter artist name",
    style = {'description_width': 'initial'}
)
artist_run_button = widgets.Button(description = "Run Artist Analysis")
artist_run_button.on_click(lambda _: run_artist_functionality(artist_name_input.value))
button_name_list = widgets.Button(description = "Show Artist List")
button_name_list.on_click(display_artist_list)

# Top 5 artists widget
top5_description1 = widgets.HTML(
    "<b>Top 5 Artists:</b> Discover the top 5 artists for a specified year range,\
    based on the number of their songs, their songs' popularity and their songs' danceability.\
    The specified year range must be within 1998-2020."
)
top5_description2 = widgets.HTML(
    "<b>Formula used to calculate rank:</b> \
    Value = (10 x Number of Songs) + (50 x Average Danceability) + (0.7 x Average Popularity)"
)
top5_start_year_input = widgets.IntText(
    description = "Start Year:",
    value = 1998,
    min = 1998,     # Minimum value
    max = 2019,    # Maximum value
    style = {'description_width': 'initial'}
)
top5_end_year_input = widgets.IntText(
    description = "End Year:",
    value = 2020,
    min = 1999,     # Minimum value
    max = 2020,    # Maximum value
    style = {'description_width': 'initial'}
)
top5_run_button = widgets.Button(description = "Run Top 5 Analysis")
top5_run_button.on_click(lambda _: run_top5_functionality(top5_start_year_input.value, top5_end_year_input.value))

# Combine widgets for each functionality
genre_box = widgets.VBox([
    genre_description,
    genre_year_input,
    genre_run_button,
    genre_output
])

artist_box = widgets.VBox([
    artist_description,
    artist_name_input, 
    widgets.HBox([button_name_list, artist_run_button]),
    artist_output
])

top5_box = widgets.VBox([
    top5_description1,
    top5_description2,
    widgets.HBox([top5_start_year_input, top5_end_year_input]),
    top5_run_button,
    top5_output
])

# Main menu layout
menu_title = widgets.HTML("<h2>Main Menu</h2>")
menu_instructions = widgets.HTML(
    "<p>Select one of the functionalities below and provide the required input.\
    Then press the 'Run ...' button to view the analysis.</p>"
)
menu_tabs = widgets.Tab([genre_box, artist_box, top5_box])
menu_tabs.set_title(0, "Genre Analysis")
menu_tabs.set_title(1, "Artist Analysis")
menu_tabs.set_title(2, "Top 5 Artists")

# Display everything
display(menu_title, menu_instructions, menu_tabs)
# Out:
# HTML(value='<h2>Main Menu</h2>')
# HTML(value="<p>Select one of the functionalities below and provide the required input.    Then press the 'Run …
# Tab(children=(VBox(children=(HTML(value='<p><b>Genre Analysis:</b> Analyse the danceability, popularity, exple…

# %% [markdown]
# The main GUI has 3 tabs, each of which can call a main function from one of Genres.py, Artist.py and Top5.py; presenting each analysis with a table and a visualisation.

# %% [markdown]
# ## Testing

# %% [markdown]
# Each of the following lines calls a .py file directly, hence calling the testing codes at the end of each program. Remove the hash at the start of a line to run.

# %%
# !python Preprocessing.py
# !python Genres.py
# !python Artist.py
# !python Top5.py
# Out:
# duration column (test data):
# 0      0
# 1    250
# 2    160
# 3     20
# Name: duration, dtype: int64
# Song names after filter test:
#         song   artist genre  duration  ...  year  popularity  danceability  speech
# 0      Song1  Artist1   Pop         0  ...  2018          60           0.7     0.4
# 1      Song2  Artist2  Rock       250  ...  2019          55           0.6     0.5
# 2      Song3  Artist3   Pop       160  ...  2020          65           0.8     0.3
#
# [3 rows x 9 columns]
# filter1() passed.
# Song Table:
# ('Party Up', 269, 1, 1999, 71, 0.51, 0.347, 1, 1)
# ('Survivor', 254, 0, 2001, 70, 0.514, 0.41, 2, 2)
# ('Peaches & Cream', 193, 0, 2001, 63, 0.677, 0.334, 3, 3)
# ('Because I Got High', 198, 1, 2001, 68, 0.802, 0.488, 4, 4)
# ('Izzo (H.O.V.A.)', 241, 1, 2001, 63, 0.618, 0.342, 5, 4)
# ('I Need a Girl (Pt. 2) [feat. Loon, Ginuwine & Mario Winans]', 286, 0, 2004, 69, 0.713, 0.483, 6, 1)
# ('The Whole World (feat. Killer Mike)', 295, 1, 2001, 51, 0.814, 0.401, 7, 1)
# ('In Da Club', 193, 1, 2003, 81, 0.899, 0.366, 8, 1)
# ('P.I.M.P.', 249, 1, 2003, 76, 0.712, 0.346, 8, 1)
# ('Never Leave You (Uh Oooh, Uh Oooh)', 185, 0, 2003, 61, 0.811, 0.362, 9, 2)
# ('Gossip Folks (feat. Ludacris)', 235, 1, 2002, 57, 0.707, 0.505, 10, 3)
# ('Stand Up', 214, 1, 2003, 57, 0.751, 0.349, 11, 1)
# ("Can't Let You Go (feat. Mike Shorey & Lil' Mo)", 224, 1, 2003, 61, 0.646, 0.458, 12, 3)
# ('Lean Back', 247, 1, 2004, 67, 0.783, 0.415, 13, 4)
# ('Call on Me - Radio Mix', 171, 0, 2004, 72, 0.597, 0.375, 14, 5)
# ('All Falls Down', 224, 1, 2004, 80, 0.657, 0.484, 15, 4)
# ('Gold Digger', 208, 1, 2005, 78, 0.629, 0.348, 15, 4)
# ('Candy Shop', 209, 1, 2005, 79, 0.614, 0.466, 8, 1)
# ('Just A Lil Bit', 238, 1, 2005, 76, 0.489, 0.41, 8, 1)
# ('Ass Like That', 265, 1, 2004, 52, 0.646, 0.366, 16, 4)
# ('Laffy Taffy', 224, 1, 2005, 63, 0.891, 0.428, 17, 1)
# ("Soldier (feat. T.I. & Lil' Wayne)", 326, 0, 2004, 63, 0.878, 0.361, 2, 2)
# ('1 Thing', 239, 0, 2008, 52, 0.636, 0.332, 18, 3)
# ('Wait (The Whisper Song)', 179, 1, 2005, 57, 0.933, 0.347, 19, 1)
# ('Like Toy Soldiers', 297, 1, 2004, 67, 0.52, 0.359, 16, 4)
# ('Irreplaceable', 228, 0, 2007, 70, 0.447, 0.382, 20, 2)
# ('Touch It', 215, 1, 2006, 61, 0.658, 0.37, 21, 1)
# ('London Bridge', 241, 1, 2006, 57, 0.769, 0.357, 22, 2)
# ('Deja Vu (feat. Jay-Z)', 240, 0, 2007, 57, 0.644, 0.341, 20, 2)
# ("When I'm Gone", 281, 1, 2005, 68, 0.618, 0.352, 16, 4)
# ('Touch The Sky', 237, 1, 2005, 73, 0.552, 0.342, 15, 4)
# ('Ms. New Booty', 253, 1, 2005, 62, 0.64, 0.416, 23, 6)
# ('I Wish I Was a Punk Rocker (with Flowers in My Hair)', 152, 0, 2006, 61, 0.7, 0.358, 24, 7)
# ("This Is Why I'm Hot", 254, 1, 2007, 59, 0.621, 0.576, 25, 1)
# ('You', 273, 0, 2007, 70, 0.412, 0.47, 26, 3)
# ("Throw Some D's", 264, 1, 2007, 57, 0.697, 0.43, 27, 1)
# ("Now You're Gone - Video Edit", 148, 0, 2008, 63, 0.639, 0.354, 28, 8)
# ('My Life', 321, 1, 2008, 60, 0.673, 0.349, 29, 1)
# ('Suffocate - Superclean', 220, 0, 2007, 58, 0.458, 0.361, 30, 9)
# ('Superstar (feat. Matthew Santos)', 289, 0, 2007, 64, 0.572, 0.361, 31, 1)
# ('Empire State Of Mind', 277, 1, 2009, 82, 0.491, 0.392, 5, 4)
# ('Break Up', 249, 1, 2009, 51, 0.44, 0.363, 32, 2)
# ('Forever', 358, 1, 2009, 73, 0.457, 0.342, 33, 3)
# ('Like A G6', 217, 0, 2010, 73, 0.435, 0.449, 34, 1)
# ('Imma Be', 258, 0, 2009, 61, 0.597, 0.365, 35, 1)
# ('My Chick Bad', 217, 1, 2010, 68, 0.624, 0.378, 11, 1)
# ('Right Above It', 272, 1, 2010, 68, 0.376, 0.356, 36, 1)
# ('Magic (feat. Rivers Cuomo)', 196, 0, 2010, 65, 0.549, 0.343, 37, 1)
# ('I Need A Doctor', 284, 1, 2011, 71, 0.594, 0.452, 38, 4)
# ('Swimming Pools (Drank) - Extended Version', 314, 1, 2012, 63, 0.716, 0.404, 39, 4)
# ('Mercy', 329, 1, 2012, 73, 0.563, 0.406, 15, 4)
# ('Rack City', 203, 1, 2012, 61, 0.929, 0.371, 40, 1)
# ('The Motto', 182, 1, 2011, 74, 0.766, 0.356, 33, 3)
# ('We Own It (Fast & Furious)', 228, 0, 2013, 69, 0.563, 0.402, 41, 1)
# ('Berzerk', 239, 1, 2013, 66, 0.739, 0.333, 16, 4)
# ('Hot N*gga', 195, 1, 2014, 73, 0.794, 0.42, 42, 1)
# ('Panda', 247, 1, 2016, 70, 0.576, 0.449, 43, 1)
# ('2 Phones', 240, 1, 2016, 69, 0.895, 0.358, 44, 1)
# ('Treat You Better', 188, 0, 2017, 82, 0.444, 0.341, 45, 8)
# ('Gold', 226, 0, 2015, 55, 0.6, 0.344, 46, 10)
# ("Don't Mind", 198, 1, 2016, 63, 0.464, 0.336, 47, 4)
# ('Mask Off', 205, 1, 2017, 79, 0.833, 0.431, 48, 1)
# ('Bank Account', 220, 1, 2017, 74, 0.884, 0.35, 49, 4)
# ('Rake It Up (feat. Nicki Minaj)', 276, 1, 2017, 67, 0.91, 0.344, 50, 1)
# ('Youngblood', 203, 0, 2018, 69, 0.596, 0.463, 51, 8)
# ('Yes Indeed', 142, 1, 2018, 79, 0.963, 0.53, 52, 4)
# ('River (feat. Ed Sheeran)', 221, 1, 2017, 72, 0.748, 0.516, 16, 4)
# ('BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj)', 237, 1, 2018, 68, 0.745, 0.331, 53, 1)
# ('No Brainer', 260, 1, 2018, 67, 0.552, 0.342, 54, 1)
# ("I'm Upset", 214, 1, 2018, 68, 0.899, 0.343, 33, 3)
# ('bad guy', 194, 0, 2019, 83, 0.701, 0.375, 55, 5)
# ('7 rings', 179, 1, 2019, 83, 0.778, 0.334, 56, 8)
# ('Keisha & Becky - Remix', 253, 1, 2019, 69, 0.863, 0.478, 57, 8)
# ('Adan y Eva', 257, 0, 2019, 72, 0.767, 0.336, 58, 11)
# ('Pop Out (feat. Lil Tjay)', 167, 1, 2019, 78, 0.772, 0.467, 59, 4)
# ('Vossi Bop', 196, 1, 2019, 64, 0.682, 0.339, 60, 12)
# ('boyfriend (with Social House)', 186, 1, 2019, 77, 0.4, 0.461, 56, 8)
# ('Suge', 163, 1, 2019, 72, 0.876, 0.426, 61, 4)
# ('bury a friend', 193, 0, 2019, 75, 0.905, 0.332, 55, 5)
# ('Otro Trago', 226, 1, 2019, 71, 0.746, 0.341, 62, 13)
# Genre Table:
# ('hip hop, pop', 1)
# ('pop, R&B', 2)
# ('hip hop, pop, R&B', 3)
# ('hip hop', 4)
# ('pop, Dance/Electronic', 5)
# ('hip hop, pop, country', 6)
# ('World/Traditional, pop', 7)
# ('pop', 8)
# ('hip hop, pop, R&B, Dance/Electronic', 9)
# ('rock, pop, Dance/Electronic', 10)
# ('hip hop, latin, Dance/Electronic', 11)
# ('hip hop, Dance/Electronic', 12)
# ('latin', 13)
# Artist Table:
# ('DMX', 1)
# ("Destiny's Child", 2)
# ('112', 3)
# ('Afroman', 4)
# ('JAY-Z', 5)
# ('Diddy', 6)
# ('Outkast', 7)
# ('50 Cent', 8)
# ('Lumidee', 9)
# ('Missy Elliott', 10)
# ('Ludacris', 11)
# ('Fabolous', 12)
# ('Terror Squad', 13)
# ('Eric Prydz', 14)
# ('Kanye West', 15)
# ('Eminem', 16)
# ('D4L', 17)
# ('Amerie', 18)
# ('Ying Yang Twins', 19)
# ('Beyoncé', 20)
# ('Busta Rhymes', 21)
# ('Fergie', 22)
# ('Bubba Sparxxx', 23)
# ('Sandi Thom', 24)
# ('MiMS', 25)
# ('Lloyd', 26)
# ('Rich Boy', 27)
# ('Basshunter', 28)
# ('The Game', 29)
# ('J. Holiday', 30)
# ('Lupe Fiasco', 31)
# ('Mario', 32)
# ('Drake', 33)
# ('Far East Movement', 34)
# ('Black Eyed Peas', 35)
# ('Lil Wayne', 36)
# ('B.o.B', 37)
# ('Dr. Dre', 38)
# ('Kendrick Lamar', 39)
# ('Tyga', 40)
# ('2 Chainz', 41)
# ('Bobby Shmurda', 42)
# ('Desiigner', 43)
# ('Kevin Gates', 44)
# ('Shawn Mendes', 45)
# ('Kiiara', 46)
# ('Kent Jones', 47)
# ('Future', 48)
# ('21 Savage', 49)
# ('Yo Gotti', 50)
# ('5 Seconds of Summer', 51)
# ('Lil Baby', 52)
# ('YG', 53)
# ('DJ Khaled', 54)
# ('Billie Eilish', 55)
# ('Ariana Grande', 56)
# ('Russ Millions', 57)
# ('Paulo Londra', 58)
# ('Polo G', 59)
# ('Stormzy', 60)
# ('DaBaby', 61)
# ('Sech', 62)
# Year 0 is invalid.
# Year 1997 is invalid.
# Year 1998 is valid.
# Year 2000 is valid.
# Year 2020 is valid.
# Year 2021 is invalid.
# Year invalid is invalid.
# Year 2000 is valid.
#
# Testing retrieve_songs in 2000:
# No data available for the year 2000.
#
# Testing retrieve_songs in 2019:
# Retrieved 10 songs for the year 2019.
#
# Testing stats_by_genre:
# Genre statistics:
#                genre avg_danceability avg_popularity explicit_pct  song_count
# 0            hip hop             0.77           71.5         75.0           4
# 1                pop             0.73           77.4         60.0           5
# 2                R&B             Null           Null         Null           0
# 3   Dance/Electronic             0.76           73.5         25.0           4
# 4            country             Null           Null         Null           0
# 5  World/Traditional             Null           Null         Null           0
# 6               rock             Null           Null         Null           0
# 7              latin             0.76           71.5         50.0           2
#
# Testing style_table:
# Styled statistics generated successfully.
#
# Testing stats_vis:
# Generating visualizations...
# Figure(1400x600)
# Visualizations generated successfully.
#
# Testing main function:
# Testing valid year input which is empty:
# There is no data available for the year 2000.
# Testing valid year input:
# <pandas.io.formats.style.Styler object at 0x139a676e0>
# Figure(1400x600)
#
# Testing invalid year input:
# This is not a valid year.
# Please make sure to enter a year in the range 1998-2020.
# Testing artist_input():
# Passed
# Artist 'DMX' found in the database.
# Passed
#
# Testing popularity_analysis() function:
# Popularity table for DMX:
# <pandas.io.formats.style.Styler object at 0x13f65c3b0>
# Figure(1000x600)
#
# Testing main function:
# Artist 'DMX' found in the database.
# Popularity table for DMX:
# <pandas.io.formats.style.Styler object at 0x13f86fad0>
# Figure(1000x600)
# Testing year_check():
# Invalid year range. Please enter years between 1998 and 2020.
# Passed
# Passed
# Invalid year range. Please enter years between 1998 and 2020.
# Passed
#
#  Testing get_data():
#   artist  year  num_song  avg_popularity  avg_danceability
# 0    DMX  1999         1            71.0              0.51
#
#  Testing calculate_rank_values():
#   artist  year  num_song  avg_popularity  avg_danceability  rank_value
# 0    DMX  1999         1            71.0              0.51        85.2
#
#  Testing generate_table_and_chart():
# Top 5 Artists Rank Table:
# <pandas.io.formats.style.Styler object at 0x13dff3d70>
# Figure(1200x800)
#
#  Testing main():
# Top Artists Analysis
# Top 5 Artists Rank Table:
# <pandas.io.formats.style.Styler object at 0x10efbc980>
# Figure(1200x800)

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# !jupyter nbextension install --py widgetsnbextension --sys-prefix
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
